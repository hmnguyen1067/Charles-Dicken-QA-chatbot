# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import pandas as pd
import nest_asyncio
from dotenv import load_dotenv
from datetime import datetime

import qdrant_client
import gutenbergpy.textget
import opik

from charles_dicken_qa_chatbot.constants import *

# from IPython.display import Markdown, display
from llama_index.core import Settings, Document, global_handler, set_global_handler
from llama_index.vector_stores.qdrant import QdrantVectorStore
from llama_index.embeddings.fastembed import FastEmbedEmbedding
from llama_index.llms.openai import OpenAI
from llama_index.embeddings.openai import OpenAIEmbedding

# %%
nest_asyncio.apply()

today = datetime.now().strftime("%Y-%m-%d")

load_dotenv()
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
os.environ["OPIK_PROJECT_NAME"] = os.getenv(
    "OPIK_PROJECT_NAME", f"charles-dicken-qa-{today}"
)

opik.configure(api_key=os.getenv("OPIK_API_KEY"))
set_global_handler("opik")
opik_callback_handler = global_handler

opik_client = opik.Opik()
# Out:
# OPIK: Opik is already configured. You can check the settings by viewing the config file at /Users/hmnguyen1067/.opik.config

# %%
# embed_model = FastEmbedEmbedding(model_name=EMBED_MODEL)
embed_model = OpenAIEmbedding()
llm = OpenAI(model=LLM_MODEL)

Settings.embed_model = embed_model
Settings.llm = llm

# %%
client = qdrant_client.QdrantClient(host=QDRANT_HOST, port=QDRANT_PORT, timeout=120)
aclient = qdrant_client.AsyncQdrantClient(
    host=QDRANT_HOST, port=QDRANT_PORT, timeout=120
)

vector_store = QdrantVectorStore(
    client=client,
    aclient=aclient,
    enable_hybrid=True,
    fastembed_sparse_model=SPARSE_EMBEDDING_MODEL,
    collection_name=COLLECTION_NAME,
)

# %%
path = "../data/test.csv"
df = pd.read_csv(path)
df
# Out:
#    Gutenberg ID              Title
# 0            46  A Christmas Carol

# %%
from llama_index.readers.wikipedia import WikipediaReader

reader = WikipediaReader()

docs = []

for _, row in df.iterrows():
    book_id = row["Gutenberg ID"]
    book_title = row["Title"]
    book_text = (
        gutenbergpy.textget.get_text_by_id(book_id)
        .decode("utf-8")
        .replace("\r\n", "\n")
    )
    wiki_doc = reader.load_data(pages=[book_title])
    docs.extend(
        [
            Document(text=book_text, metadata={"title": book_title, "source": "book"}),
            Document(
                text=wiki_doc[0].text,
                metadata={"title": book_title, "source": "wikipedia"},
            ),
        ]
    )

# %%
from llama_index.core.extractors import (
    KeywordExtractor,
    SummaryExtractor,
    QuestionsAnsweredExtractor,
)
from llama_index.core.node_parser import (
    TokenTextSplitter,
    SentenceSplitter,
    SemanticSplitterNodeParser,
)

#
# splitter = TokenTextSplitter(
#     chunk_size=512,
#     chunk_overlap=128,
#     separator=" ",
# )

# Semantic splitter
# splitter = SemanticSplitterNodeParser(
#     buffer_size=1,
#     breakpoint_percentile_threshold=75,
#     embed_model=embed_model,
# )

# Sentence splitter
splitter = SentenceSplitter(
    chunk_size=512,
    chunk_overlap=64,
    include_metadata=True,
)

# Late chunking
# JinaAI

# QuestionsAnsweredExtractor(questions=3)
# summary_extractor = SummaryExtractor(summaries=["prev", "self"])
# keyword_extractor = KeywordExtractor(keywords=10)

# %%
from llama_index.core.ingestion import (
    IngestionPipeline,
    IngestionCache,
    DocstoreStrategy,
)
from llama_index.storage.kvstore.redis import RedisKVStore as RedisCache
from llama_index.storage.docstore.redis import RedisDocumentStore
from llama_index.storage.index_store.redis import RedisIndexStore


redis_docstore = RedisDocumentStore.from_host_and_port(
    host=REDIS_HOST, port=REDIS_PORT, namespace=COLLECTION_NAME
)
redis_indexstore = RedisIndexStore.from_host_and_port(
    host=REDIS_HOST, port=REDIS_PORT, namespace=COLLECTION_NAME
)
redis_cache = IngestionCache(
    cache=RedisCache.from_host_and_port(host=REDIS_HOST, port=REDIS_PORT),
    collection=COLLECTION_NAME,
)

# %%
pipeline = IngestionPipeline(
    transformations=[splitter, embed_model],
    vector_store=vector_store,
    docstore=redis_docstore,
    cache=redis_cache,
    docstore_strategy=DocstoreStrategy.UPSERTS,
)

nodes = await pipeline.arun(documents=docs, in_place=True, show_progress=True)

# %%
from llama_index.core import StorageContext, VectorStoreIndex

storage_context = StorageContext.from_defaults(
    docstore=redis_docstore, vector_store=vector_store, index_store=redis_indexstore
)

# %%
index = VectorStoreIndex(
    nodes=nodes,
    use_async=True,
    storage_context=storage_context,
    embed_model=embed_model,
)

# %%
# from llama_index.core import load_indices_from_storage

# re_index = load_indices_from_storage(storage_context=storage_context)

# %% [markdown]
# ## Evaluation dataset generation

# %%
from llama_index.core.llama_dataset.generator import RagDatasetGenerator

eval_llm = OpenAI(model=LLM_MODEL, temperature=0.1)

dataset_generator = RagDatasetGenerator(
    nodes,
    llm=eval_llm,
    show_progress=True,
    num_questions_per_chunk=2,
)

# %%
rag_dataset = await dataset_generator.agenerate_dataset_from_nodes()
# Out:
#   0%|          | 0/122 [00:00<?, ?it/s]OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 1ada7f16-9e59-48f1-9c3c-05ecf9b6d9f8, event_type: CBEventType.RETRIEVE, event_id: 6b5f627d-481e-4570-b7be-8bbfd2764b3f.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: a901054d-fc51-4643-9c75-73d4b769218b, event_type: CBEventType.CHUNKING, event_id: 807b252b-a308-47bc-be4c-13059e57dc7c.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: a901054d-fc51-4643-9c75-73d4b769218b, event_type: CBEventType.CHUNKING, event_id: 8b317c50-19ae-4063-af58-a5ae1bdb61dc.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: c8d81606-27f3-4c0e-9c40-8463b760e0f3, event_type: CBEventType.RETRIEVE, event_id: 03e3e82b-13c1-4de4-883b-cf1cc79c37b3.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 933a7396-c115-4c0b-9539-352d334b6582, event_type: CBEventType.CHUNKING, event_id: 98fbef16-82d6-45ed-9b25-8b518130cb78.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 933a7396-c115-4c0b-9539-352d334b6582, event_type: CBEventType.CHUNKING, event_id: d249648a-f86f-452d-ad3c-583776db9e60.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 3e87cf32-6870-47d0-a02c-f99e012a83e6, event_type: CBEventType.RETRIEVE, event_id: ef1a1526-40b5-47e5-83ed-336dd02b4a6c.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 1ff418ad-1c86-47dd-b77e-fd5509b51eec, event_type: CBEventType.CHUNKING, event_id: d2ee5c4d-ea55-45ec-9dd0-88671e40e2c2.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 1ff418ad-1c86-47dd-b77e-fd5509b51eec, event_type: CBEventType.CHUNKING, event_id: f0e52e0c-7bb8-4775-8db2-fa8805d2688c.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id:
/it]OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: cd3aee07-4666-4b7a-b565-c1c0493abd79, event_type: CBEventType.RETRIEVE, event_id: 4a11daae-4dad-4ce5-9805-b11e03fa16a2.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: e58c41cf-842d-4219-a2ef-6742e5bed15a, event_type: CBEventType.CHUNKING, event_id: 9068b78f-cee6-49b7-b40e-48c8a6521704.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: e58c41cf-842d-4219-a2ef-6742e5bed15a, event_type: CBEventType.CHUNKING, event_id: 7400d8ed-206d-4204-b971-387fdd41fc09.
#  10%|▉         | 12/122 [00:51<06:02,  3.30s/it]OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: beab1819-9555-4912-8a7e-1b6e77d167ca, event_type: CBEventType.RETRIEVE, event_id: 0a8b91c1-d5f8-4ede-8508-12a3b3708650.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: c05d54b4-14f0-4873-b1cb-2839497fa9e7, event_type: CBEventType.CHUNKING, event_id: db53a71b-ff6a-4da0-8e34-68c7453ced21.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: c05d54b4-14f0-4873-b1cb-2839497fa9e7, event_type: CBEventType.CHUNKING, event_id: 8532522d-4fc5-4f2e-b0cc-394ddf218d90.
#  11%|█         | 13/122 [00:54<05:35,  3.08s/it]OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 0d18a793-bdb9-4d90-8e60-b8e4ac2df419, event_type: CBEventType.RETRIEVE, event_id: 3ca253d9-5a3f-4e8b-9bcc-a9ce24e6bf45.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 988c1cb4-826a-486b-a8a6-fb4207268759, event_type: CBEventType.CHUNKING, event_id: ee98a32a-afc3-4e54-8796-9571e27f054e.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 988c1cb4-826a-486b-a8a6-fb4207268759, event_type: CBEventType.CHUNKING, event_id: a7127333-9c7a-45f4-95ff-342f056ea1cb.
#  11%|█▏        | 14/122 [00:57<05:54,  3.28s/it]OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 6f32fe7e-b847-4674-8c29-f1f00b3e5d87, event_type: CBEventType.RETRIEVE, event_id: 73a56520-47cf-4468-a647-1268cccb8a83.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 01cb6e07-3d77-483d-96d2-938259367eb0, event_type: CBEventType.CHUNKING, event_id: 077e2c73-847f-4013-816f-f2a957bbacef.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 01cb6e07-3d77-483d-96d2-938259367eb0, event_type: CBEventType.CHUNKING, event_id: d4d44fb9-da69-4d20-a0e5-67e290744ef0.
#  12%|█▏        | 15/122 [00:59<05:09,  2.90s/it]OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: df75031c-37f0-4a4a-b8ac-c38d880b4452, event_type: CBEventType.RETRIEVE, event_id: 0eadcc4d-4f24-4bcd-bdab-f995f50a0181.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: a5c64db7-6709-4a41-a987-094bf5071618, event_type: CBEventType.CHUNKING, event_id: d5c2a20d-66ea-4403-82b0-828a98ab826d.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: a5c64db7-6709-4a41-a987-094bf5071618, event_type: CBEventType.CHUNKING, event_id: 338f9b2f-fe2a-494b-aa3f-95ee52bade1c.
#  13%|█▎        | 16/122 [01:03<05:18,  3.01s/it]OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 86193f4a-aaf1-4937-a89d-250cfe7d4fbe, event_type: CBEventType.RETRIEVE, event_id: 2885e255-a86b-495e-bb0a-7c6612cc3594.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 420cf664-a2eb-428a-ade1-478f827a184d, event_type: CBEventType.CHUNKING, event_id: 3b09c6fa-6bac-42a2-a6b5-59deff3ae8d5.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id:

# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 01d583f8-1c43-4950-9659-dde5c527df99, event_type: CBEventType.CHUNKING, event_id: 05010b95-9e42-4311-860c-412ec5aa4fd6.
#  43%|████▎     | 52/122 [03:03<04:26,  3.81s/it]OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 1f01f151-9ff5-437b-a61a-44c46b8f6258, event_type: CBEventType.RETRIEVE, event_id: 14b72e6b-9320-44b4-ad56-79a934471eb2.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 26d73918-3097-47de-a238-9cf010a9516f, event_type: CBEventType.CHUNKING, event_id: c150b467-a2c1-446a-8010-0854daca4008.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 26d73918-3097-47de-a238-9cf010a9516f, event_type: CBEventType.CHUNKING, event_id: 6584564b-dae3-4d62-be8e-015cdaa0648d.
#  43%|████▎     | 53/122 [03:04<03:22,  2.93s/it]OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 17813a76-9c8c-4c2b-acd3-6ff440a9a1ea, event_type: CBEventType.RETRIEVE, event_id: 2399b6d1-9f7f-4080-b4ce-5c33f8ecd7e8.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 21806384-7b56-4c2b-bb7a-e63d824e099d, event_type: CBEventType.CHUNKING, event_id: 057c92ae-611f-42d4-97f0-b48f111206b6.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 21806384-7b56-4c2b-bb7a-e63d824e099d, event_type: CBEventType.CHUNKING, event_id: 64632fe3-b28f-4453-b546-4751b3a36cdb.
# ...
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: acef6f03-b812-4c36-b959-4c33246f2b0b, event_type: CBEventType.CHUNKING, event_id: ebdc65be-fc59-4a22-8462-f8e4f53609d4.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 80184b50-c62c-4094-9a8d-2a2a79fb2d2e, event_type: CBEventType.RETRIEVE, event_id: b212a2f3-c731-4ccc-8c9d-8903aad9e7bd.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 9d8c49fe-852f-480a-9ec9-616b1cf3c4ba, event_type: CBEventType.CHUNKING, event_id: 1eb38019-af9d-4507-91a3-d09e13921808.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 9d8c49fe-852f-480a-9ec9-616b1cf3c4ba, event_type: CBEventType.CHUNKING, event_id: bc38fbe8-6afd-4322-9d93-95efd0c4050c.
# 100%|██████████| 2/2 [00:08<00:00,  4.48s/it]
#   0%|          | 0/2 [00:00<?, ?it/s]OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 3e101530-2ea5-4eb6-ac48-9235eae2eec8, event_type: CBEventType.RETRIEVE, event_id: 0be9ddde-fde4-4f10-a66b-b239642c9d3d.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 2b999ee8-1fa5-491f-bab0-a94371195895, event_type: CBEventType.CHUNKING, event_id: 2e72fb48-8c36-4ba1-a999-5096da9ac92d.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 2b999ee8-1fa5-491f-bab0-a94371195895, event_type: CBEventType.CHUNKING, event_id: ba77cfd5-390f-4120-aada-1cfb950d562a.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: a806b9e6-4d98-46be-bd74-9ee59d4fd8ae, event_type: CBEventType.RETRIEVE, event_id: db41051b-b8eb-4daa-a500-bff1ce120ede.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 8ed4a3d4-cdd1-4af5-ae56-6f39c0a67ed8, event_type: CBEventType.CHUNKING, event_id: 12f2d2ed-c413-4cb8-83c9-2a8a34d1b386.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 8ed4a3d4-cdd1-4af5-ae56-6f39c0a67ed8, event_type: CBEventType.CHUNKING, event_id: f8a93af1-e22f-4db7-94cc-558ae982c27e.
# 100%|██████████| 2/2 [00:06<00:00,  3.23s/it]
#   0%|          | 0/2 [00:00<?, ?it/s]OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 78d0d476-1a54-4bb8-b1dd-30098fdf2123, event_type: CBEventType.RETRIEVE, event_id: 20cf3da2-33e5-4411-8f02-c918e9ac3d1e.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id

# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 287cc05c-49b2-4d67-bf86-d87d30a7471e, event_type: CBEventType.CHUNKING, event_id: e74255cf-997f-440f-8d24-45931c98d17b.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 6c8c59b9-abd2-464c-bc00-780f22dd69bd, event_type: CBEventType.RETRIEVE, event_id: 56966e44-a5d2-4cc5-8391-b3ee7b9eae4d.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 6c2f4689-ab3c-43dc-b524-bb55946b0179, event_type: CBEventType.CHUNKING, event_id: 7a272d43-88fe-4ac4-a4b8-a6304ebfcef1.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 6c2f4689-ab3c-43dc-b524-bb55946b0179, event_type: CBEventType.CHUNKING, event_id: c4783adc-af3c-49af-9ab2-1fc71584dc49.
# 100%|██████████| 2/2 [00:08<00:00,  4.06s/it]
#   0%|          | 0/2 [00:00<?, ?it/s]OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 4ee0ac59-c270-4b8c-9611-d302393814c9, event_type: CBEventType.RETRIEVE, event_id: b124750f-071f-4a17-ab6b-bcf04a67a0fd.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 5b59307a-a55c-4015-afb4-4c240bfb4fe8, event_type: CBEventType.CHUNKING, event_id: f78dd150-f68b-48e1-8ce8-3b55189f284d.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 5b59307a-a55c-4015-afb4-4c240bfb4fe8, event_type: CBEventType.CHUNKING, event_id: 7fd5fa1f-4591-4a1e-8e38-4c00914165d9.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: d01476d0-be65-4457-ba4a-d9ac3cae7715, event_type: CBEventType.RETRIEVE, event_id: 6852fa08-91ee-413f-8490-9706609b6df0.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 488f68b6-399c-4c96-b437-26dd1eb6ff54, event_type: CBEventType.CHUNKING, event_id: ad9baf1e-8cce-47a0-a75f-09850759aadb.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 488f68b6-399c-4c96-b437-26dd1eb6ff54, event_type: CBEventType.CHUNKING, event_id: 76e1e8d4-4f1b-4148-943d-12a1fcfea7bd.
# 100%|██████████| 2/2 [00:02<00:00,  1.49s/it]

# %%
query_engine = index.as_query_engine(
    similarity_top_k=2,
    sparse_top_k=8,
    vector_store_query_mode="hybrid",
    hybrid_top_k=3,
    llm=llm,
)

# %% [markdown]
# # Opik

# %%
from opik.evaluation.metrics import (
    Hallucination,
    Usefulness,
    AnswerRelevance,
    ContextPrecision,
    ContextRecall,
)
from opik.evaluation import evaluate

# %%
opik_eval_name = (
    f"{COLLECTION_NAME}-eval-{len(rag_dataset.examples)}-{LLM_MODEL}-{today}"
)
dataset = opik_client.get_or_create_dataset(name=opik_eval_name)
# Out:
# OPIK: Created a "charles_dickens-eval-244-gpt-5-nano-2025-09-25" dataset at https://www.comet.com/opik/api/v1/session/redirect/datasets/?dataset_id=01998176-3cbd-70b1-85dc-eb00f97c4793&path=aHR0cHM6Ly93d3cuY29tZXQuY29tL29waWsvYXBpLw==.

# %%
dataset.insert_from_pandas(rag_dataset.to_pandas())

# %%
dataset.to_pandas()
# Out:
#                                       reference_answer  \
# 0                                             LibriVox
# 1    Dickens Christmas fair; List of Christmas-them...
# 2    - Shift 1: Early 20th century transformation i...
# 3    - Robert Louis Stevenson\n- An American busine...
# 4    - William Dean Howells\n  - View: Howells anal...
# ..                                                 ...
# 239  - "tight-fisted hand at the grind-stone"  \n  ...
# 240  Dickens uses humor and literary allusion in th...
# 241  They are depicted as lifelong business partner...
# 242                  "MARLEY was dead: to begin with."
# 243  - He aims to raise the Ghost of an Idea.\n- He...
#
#                                                  query         query_by  \
# 0    According to the External links section, name ...  ai (gpt-5-nano)
# 1    Name two items listed in the See also section ...  ai (gpt-5-nano)
# 2    - Question 2 (analytical): Explain two major s...  ai (gpt-5-nano)
# 3    - Question 1 (factual): Name two individuals o...  ai (gpt-5-nano)
# 4    Analytical: Compare the critiques of A Christm...  ai (gpt-5-nano)
# ..                                                 ...              ...
# 239  Identify and quote at least five descriptive p...  ai (gpt-5-nano)
# 240  The narrator uses humorous asides and allusion...  ai (gpt-5-nano)
# 241  Provide a concise description of Scrooge and M...  ai (gpt-5-nano)
# 242  Multiple choice: Stave I opens by stating Marl...  ai (gpt-5-nano)
# 243  Short answer: According to the Preface, what i...  ai (gpt-5-nano)
#
#                                     reference_contexts reference_answer_by  \
# 0    [== See also ==\n\nChristmas horror\nDickens C...     ai (gpt-5-nano)
# 1    [== See also ==\n\nChristmas horror\nDickens C...     ai (gpt-5-nano)
# 2    [Ruth Glancy, the professor of English literat...     ai (gpt-5-nano)
# 3    [Ruth Glancy, the professor of English literat...     ai (gpt-5-nano)
# 4    [== Legacy ==\n\nThe phrase "Merry Christmas" ...     ai (gpt-5-nano)
# ..                                                 ...                 ...
# 239  [The firm was known as\nScrooge and Marley. So...     ai (gpt-5-nano)
# 240  [Old Marley was as dead as a\ndoor-nail.\n\nMi...     ai (gpt-5-nano)
# 241  [Old Marley was as dead as a\ndoor-nail.\n\nMi...     ai (gpt-5-nano)
# 242  [The Project Gutenberg eBook of A Christmas Ca...     ai (gpt-5-nano)
# 243  [The Project Gutenberg eBook of A Christmas Ca...     ai (gpt-5-nano)
#
#                                        id
# 0    01998176-8c08-7d06-8c42-bf5fe6b07b05
# 1    01998176-8c07-7866-b27b-96e752e9b82f
# 2    01998176-8c06-7539-9119-08626e069bc0
# 3    01998176-8c05-7d7f-a5b5-9c4193870c31
# 4    01998176-8c04-7a8e-a3e1-0e7c1ef735ca
# ..                                    ...
# 239  01998176-8b19-7db0-8858-45df3941a7c3
# 240  01998176-8b18-706a-af3e-ddf46c102ea3
# 241  01998176-8b17-75c3-8346-b277343cdb69
# 242  01998176-8b16-713f-89ce-ed9a638bf8e9
# 243  01998176-8b15-7f2b-8ad4-813a724ebe27
#
# [244 rows x 6 columns]

# %%
hallucination_metric = Hallucination(model=LLM_MODEL)
usefulness_metric = Usefulness(model=LLM_MODEL)
answer_relevance_metric = AnswerRelevance(model=LLM_MODEL)
context_precision_metric = ContextPrecision(model=LLM_MODEL)
context_recall_metric = ContextRecall(model=LLM_MODEL)


@opik.track
def query_vector(query, query_engine):
    response = query_engine.query(query)
    return response


def evaluation_task(x, query_engine):
    return {
        "output": query_vector(x["query"], query_engine),
        "context": x["reference_contexts"],
        "expected_output": x["reference_answer"],
    }


def make_task(query_engine):
    def _task(x):
        return evaluation_task(x, query_engine)

    return _task


task = make_task(query_engine)

evaluation = evaluate(
    dataset=dataset,
    task=task,
    scoring_metrics=[
        hallucination_metric,
        usefulness_metric,
        answer_relevance_metric,
        context_precision_metric,
        context_recall_metric,
    ],
    scoring_key_mapping={"input": "query"},
    experiment_config={"rag": "base"},
)

# %% [markdown]
# # Retriever Evaluator

# %%
dataset = opik_client.get_or_create_dataset(name=f"eval-dataset-{today}-v2")

# %%
dataset.insert_from_pandas(rag_dataset.to_pandas())

# %%
from charles_dicken_qa_chatbot.utils import *
from llama_index.core.postprocessor import SentenceTransformerRerank
from llama_index.core.evaluation import EmbeddingQAFinetuneDataset

# %%
qa_dataset = create_eval_dataset(nodes, llm=llm)
# Out:
# 100%|██████████| 122/122 [23:08<00:00, 11.38s/it]

# %%
qa_dataset.save_json("this.json")

# %%
qa_dataset = EmbeddingQAFinetuneDataset.from_json("this.json")

# %%
# nodes = set_node_ids(nodes)

# %%
similarity_top_k = 3
reranker = SentenceTransformerRerank(
    model="cross-encoder/ms-marco-MiniLM-L4-v2", top_n=similarity_top_k
)

# %%
embedding_retriever = create_embedding_retriever(
    nodes,
    storage_context=storage_context,
    embed_model=embed_model,
    similarity_top_k=similarity_top_k,
)
embedding_retriever_results = await retrieval_results(embedding_retriever, qa_dataset)

# %%
display_results("Embedding Retriever", embedding_retriever_results)
# Out:
#             retrievers  hit_rate      mrr  precision    recall       ap  \
# 0  Embedding Retriever  0.721311  0.61612   0.240437  0.721311  0.61612
#
#        ndcg
# 0  0.643244

# %%
bm25_retriever = create_bm25_retriever(
    nodes,
    similarity_top_k=similarity_top_k,
)
bm25_retriever_results = await retrieval_results(bm25_retriever, qa_dataset)
# Out:
# OPIK: Started logging traces to the "charles-dicken-qa-2025-09-25" project at https://www.comet.com/opik/api/v1/session/redirect/projects/?trace_id=019980ca-cc30-7f90-973c-693ab5503ee5&path=aHR0cHM6Ly93d3cuY29tZXQuY29tL29waWsvYXBpLw==.

# %%
display_results("BM25 Retriever", bm25_retriever_results)
# Out:
#        retrievers  hit_rate       mrr  precision    recall        ap      ndcg
# 0  BM25 Retriever  0.737705  0.669399   0.245902  0.737705  0.669399  0.686961

# %%
embedding_bm25_retriever_rerank = EmbeddingBM25RerankerRetriever(
    embedding_retriever, bm25_retriever, reranker=reranker
)
embedding_bm25_retriever_rerank_results = await retrieval_results(
    embedding_bm25_retriever_rerank, qa_dataset
)
# Out:
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 5067e34c-7272-4f13-b9e8-d08cc030e76a, event_type: CBEventType.RETRIEVE, event_id: 55d2c221-f8c3-46ab-8f7b-03222e6e7096.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 55d2c221-f8c3-46ab-8f7b-03222e6e7096, event_type: CBEventType.EMBEDDING, event_id: 6e79e3fc-5157-4ec9-af2f-dd9adc1ceaec.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: a909bbb1-175e-47f9-ab07-a7dc329ec543, event_type: CBEventType.RETRIEVE, event_id: b6a94a5e-b359-472b-8a50-62ed2fea6d49.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: b6a94a5e-b359-472b-8a50-62ed2fea6d49, event_type: CBEventType.EMBEDDING, event_id: 7b5a72af-548a-4de1-82f9-81a21e416aae.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 1a0378d8-5d57-4ecf-8ff3-ba987ce8a45b, event_type: CBEventType.RETRIEVE, event_id: 5b1aa699-fb91-4e22-9ea7-851957fe3a72.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id:

# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 164874f4-eed8-4c10-b7e2-8e0581902ea4, event_type: CBEventType.EMBEDDING, event_id: 1efdb743-940b-477d-814e-8591c77f7531.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: b3b5c879-68d1-4704-aeb8-d9857b49247d, event_type: CBEventType.RETRIEVE, event_id: 45b757bb-b3e2-49f2-a0cc-d67f834b8541.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 45b757bb-b3e2-49f2-a0cc-d67f834b8541, event_type: CBEventType.EMBEDDING, event_id: 0bb70185-6f30-42cd-8ffa-60006aceedb5.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: c6e60552-f7a9-4bf8-8b94-676ffb90b00c, event_type: CBEventType.RETRIEVE, event_id: 11797f26-2879-4e6f-b905-a668b2bca166.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 11797f26-2879-4e6f-b905-a668b2bca166, event_type: CBEventType.EMBEDDING, event_id: f569f908-12b9-4aae-b9e3-27b80eed6329.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: db4185f9-ca06-4449-9c29-6a7bc73f7e5f, event_type: CBEventType.RETRIEVE, event_id: 941af560-61c1-4e81-96c7-d2ab15364c1d.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 941af560-61c1-4e81-96c7-d2ab15364c1d, event_type: CBEventType.EMBEDDING, event_id: acb5740d-b7c3-46cc-8667-4a5fc567991d.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 234c4abc-9105-4cbb-871e-0dbb164724c7, event_type: CBEventType.RETRIEVE, event_id: 595fb852-ed99-45b5-b05a-2098bd702387.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 595fb852-ed99-45b5-b05a-2098bd702387, event_type: CBEventType.EMBEDDING, event_id: 34519634-9a1e-4b7f-9a45-9a68a08a54d3.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 39cb09c3-f04b-47c9-9c10-0e7d5de1c790, event_type: CBEventType.RETRIEVE, event_id: 28b69329-eec6-4bc6-b4f0-02d73505a45a.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 28b69329-eec6-4bc6-b4f0-02d73505a45a, event_type: CBEventType.EMBEDDING, event_id: 8eb1c249-5cf9-4342-ac73-f2017a901277.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 048530bc-3550-4160-a051-57e5031c647f, event_type: CBEventType.RETRIEVE, event_id: 67220893-8e69-43b6-9c69-c3288508bfb3.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 67220893-8e69-43b6-9c69-c3288508bfb3, event_type: CBEventType.EMBEDDING, event_id: 7b776099-29ea-49ab-92b3-febf25b7be52.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 2a1f5c88-87da-4340-93b3-bbb76ff95f98, event_type: CBEventType.RETRIEVE, event_id: f667051e-dab3-4c61-8242-4227aab585ff.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: f667051e-dab3-4c61-8242-4227aab585ff, event_type: CBEventType.EMBEDDING, event_id: 7138c3bb-8d1f-454a-8c71-04bfcf2eb66d.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 5a696145-a003-4db2-9770-76fca386cb1b, event_type: CBEventType.RETRIEVE, event_id: 03c48683-44e3-4994-9c32-41a2c5a3d5ba.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 03c48683-44e3-4994-9c32-41a2c5a3d5ba, event_type: CBEventType.EMBEDDING, event_id: 1a7ed2a8-c31a-4a9d-b183-066abba06294.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: bed51bd7-3568-472a-a4a6-428e590ac550, event_type: CBEventType.RETRIEVE, event_id: 0de41ea9-5372-4e6f-94f3-a04f620210e0.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 0de41ea9-5372-4e6f-94f3-a04f620210e0, event_type: CBEventType.EMBEDDING, event_id: 4fb662c2-bc57-4852-924a-2f83d4eb6656.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 66907c60-d4f2-4922-8230-ce9706845f99, event_type: CBEventType.RETRIEVE, event_id: 69742100-a956-4516-9325-d032600be5f9.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 69742100-a956-4516-9325-d032600be5f9, event_type: CBEventType.EMBEDDING, event_id: 930b5656-4197-46d9-84b7-b2a217518ee9.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 34b3bcc8-3dca-4d22-b9a7-a1f4482a15b0, event_type: CBEventType.RETRIEVE, event_id: 2bb68225-ce1d-4e25-9c5c-98783fa1c1c3.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 2bb68225-ce1d-4e25-9c5c-98783fa1c1c3, event_type: CBEventType.EMBEDDING, event_id: 3d7cca36-88b4-421c-af70-012405818a90.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 3c6f92e2-988d-4b7e-82bb-cedbe45c9009, event_type: CBEventType.RETRIEVE, event_id: 4e9ac7bb-8a59-4400-8f60-5a4470dd6053.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 4e9ac7bb-8a59-4400-8f60-5a4470dd6053, event_type: CBEventType.EMBEDDING, event_id: 2a734da5-0a80-4d54-a449-1cf9055ab349.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: c3838d5b-4f26-435a-81a6-201e645b00bb, event_type: CBEventType.RETRIEVE, event_id: 442395c8-8d6f-4861-b5da-1a57cfc58857.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 442395c8-8d6f-4861-b5da-1a57cfc58857, event_type: CBEventType.EMBEDDING, event_id: cc49838e-e6d8-46ea-8bc0-00033b669ef3.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 224230bf-f610-44f2-a6a0-b4a57c56772e, event_type: CBEventType.RETRIEVE, event_id: c91b7719-f1ef-429c-b4e7-4f69f8b776c9.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: c91b7719-f1ef-429c-b4e7-4f69f8b776c9, event_type: CBEventType.EMBEDDING, event_id: 3ee572d8-29e5-468e-952a-7264168b0b01.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 97e84d40-716b-4559-b927-b195ecee2d3f, event_type: CBEventType.RETRIEVE, event_id: 0162cbb9-2014-40a8-9e27-905f663a6c59.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 0162cbb9-2014-40a8-9e27-905f663a6c59, event_type: CBEventType.EMBEDDING, event_id: fec16927-0bda-481a-9038-b41407a958c5.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 82ea9690-3807-4d29-8f09-1ab867ccd77e, event_type: CBEventType.RETRIEVE, event_id: d0d6b7b2-2db1-4a12-a170-b94810f77cc0.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: d0d6b7b2-2db1-4a12-a170-b94810f77cc0, event_type: CBEventType.EMBEDDING, event_id: baf3257c-502d-41cc-91fd-264176e792f1.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 11b8c6f2-83c9-4442-b5bc-b058db591af5, event_type: CBEventType.RETRIEVE, event_id: 16b6c269-461f-47bb-a1a1-4005c5dd5594.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 16b6c269-461f-47bb-a1a1-4005c5dd5594, event_type: CBEventType.EMBEDDING, event_id: 0edfdab0-96b0-4278-b350-90e9a23d9e5b.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 17971cd3-5ec7-4f16-ad7b-6afe71cc3115, event_type: CBEventType.RETRIEVE, event_id: 78c492c3-112f-4857-9b27-37d9974a19ae.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 78c492c3-112f-4857-9b27-37d9974a19ae, event_type: CBEventType.EMBEDDING, event_id: c83b4e68-1317-4bfa-8094-7e682108f3a6.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 880c6839-8b7c-41e1-8e06-0628f4d46e61, event_type: CBEventType.RETRIEVE, event_id: 811b0118-e6ce-47cd-8724-c8aa8f4d819d.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 811b0118-e6ce-47cd-8724-c8aa8f4d819d, event_type: CBEventType.EMBEDDING, event_id: 635cdf8b-5345-4e21-9a2c-7ff78ced081b.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 781a4c13-7308-4c22-8afa-a42c3982a9bd, event_type: CBEventType.RETRIEVE, event_id: 95a5bc74-ab18-4825-9893-ed0f214cbfb7.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 95a5bc74-ab18-4825-9893-ed0f214cbfb7, event_type: CBEventType.EMBEDDING, event_id: ba66bf00-57ba-4cfb-b319-e9a4a80e5ec2.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 7317ea6f-d621-471c-9a47-613b75b09347, event_type: CBEventType.RETRIEVE, event_id: 2751eeea-adcf-42fc-a418-192d3bc91bae.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 2751eeea-adcf-42fc-a418-192d3bc91bae, event_type: CBEventType.EMBEDDING, event_id: fc205bde-d054-4809-9c49-9f3f75273e3a.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 0306ff7f-021d-4600-9b6a-1f61ba169d7a, event_type: CBEventType.RETRIEVE, event_id: e10ef574-7955-4e03-bae3-0622d04e0c67.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: e10ef574-7955-4e03-bae3-0622d04e0c67, event_type: CBEventType.EMBEDDING, event_id: 57e5ad04-6edf-4d62-867e-037d465b2f87.

# %%
display_results(
    "Embedding + BM25 Retriever + Reranker",
    embedding_bm25_retriever_rerank_results,
)
# Out:
#                               retrievers  hit_rate       mrr  precision  \
# 0  Embedding + BM25 Retriever + Reranker  0.778689  0.670082   0.358607
#
#      recall        ap     ndcg
# 0  0.778689  0.670082  0.69823

# %%
query_engine = index.as_query_engine(
    similarity_top_k=2,
    sparse_top_k=8,
    vector_store_query_mode="hybrid",
    hybrid_top_k=3,
    llm=llm,
)

# %%
bm42_retriever = query_engine.retriever
bm42_retriever_results = await retrieval_results(bm42_retriever, qa_dataset)

# %%
display_results(
    "Embedding + BM42 Retriever",
    bm42_retriever_results,
)
# Out:
#                    retrievers  hit_rate       mrr  precision    recall  \
# 0  Embedding + BM42 Retriever  0.643443  0.583333   0.214481  0.643443
#
#          ap      ndcg
# 0  0.583333  0.598944

# %%
from llama_index.core import get_response_synthesizer
from llama_index.core.query_engine import RetrieverQueryEngine

# %%
from llama_index.core.response_synthesizers import ResponseMode

# %%
response_synthesizer = get_response_synthesizer()
ensemble_query_engine = RetrieverQueryEngine(
    retriever=embedding_bm25_retriever_rerank,
    response_synthesizer=response_synthesizer,
)

# %%
response = ensemble_query_engine.query("What is 'A Christmas Carol' main theme?")
# Out:
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 45223ffd-975c-427c-baa2-df78a29d7382, event_type: CBEventType.RETRIEVE, event_id: 1727689d-6e8b-4759-b26a-13bf2572dc65.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 1727689d-6e8b-4759-b26a-13bf2572dc65, event_type: CBEventType.RETRIEVE, event_id: 07ec0a1c-9291-4ae8-8333-6a7c1d7d15a0.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: 1727689d-6e8b-4759-b26a-13bf2572dc65, event_type: CBEventType.RERANKING, event_id: ea26ef41-6004-4937-9ffd-ad41148e1f36.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: c3881a6f-b83c-4047-a290-3a4d2bed0716, event_type: CBEventType.CHUNKING, event_id: 6aad8f08-9246-42a3-a628-ba20da3fc65a.
# OPIK: No trace data found in context for event start. This is likely due to the fact that the trace is not started properly. The parent_id: c3881a6f-b83c-4047-a290-3a4d2bed0716, event_type: CBEventType.CHUNKING, event_id: 7298a8a5-81c5-4188-bc25-b0c31384f671.
